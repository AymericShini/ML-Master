# %%
# Demange Aymeric 02/10/2020
# Projet sur un dataset d'anime


import seaborn as sns
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import LabelEncoder as LE
from sklearn.model_selection import train_test_split as TTS
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier as KNN #KNeighborsRegressor
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from scipy import interp
from itertools import cycle




warnings.filterwarnings("ignore")

sns.set

# charger le dataset
dataAnime = pd.read_csv(r"/content/dataanime.csv")
df_dataAnime = dataAnime.copy()

# %%
# Cette fonction permet de convertir les tirets en "Unknown" en leur passant en argument la colonne en question

def dashToUnknown(value) :
    if (value == '-' ) :
      return 'Unknown'
    else : 
      return value

def fillEndingDate(row) :
  if ( (row.Type == 3 or row.Type == 0) and row.EndingDate == '-') :
    row.EndingDate = row.StartingDate
  return row

def getBroadcastDay(value) :
    splitted = value.split()
    return splitted[0]

def getBroadcastTime(value) :
    splitted = value.split()
    if (len(splitted)== 4) :
      return splitted[2]
    else :
      return 'Unknown'

def getSplittedByComa(value) :
    splitted = value.split(",")
    return splitted

def getSplittedByBlankSpace(value) :
    splitted = value.split()
    return splitted

def copyDf(df,dfToCopy) :
  for col in dfToCopy.columns:
      df[col] = dfToCopy[col]

def getTimePerTitle(value) :
  splitted = value.replace("-","0")
  splitted = splitted.replace("per ep.","").split()
  if (len(splitted) == 4) :
    return (int(splitted[0])*60 + int(splitted[2]))
  elif (len(splitted) == 2) :
    return (int(splitted[0]) * int(df_dataAnime.Episodes.iloc[0]))
  else :
    return (splitted[0])

# Petite fonction permettant de calculer l'accuracy et ensuite de le mettre en %
def accuracy(preds, Y):
  return ((preds == Y).sum() / len(Y)* 100)

# %% [markdown]
# ---
#
#
# # **Voici notre dataframe d'origine**
#
# ---

# %%
df_dataAnime
# Out:
#                                                   Title  ...                                        Description
# 0                      Fullmetal Alchemist: Brotherhood  ...  "In order for something to be obtained, someth...
# 1                                        Kimi no Na wa.  ...  Mitsuha Miyamizu, a high school girl, yearns t...
# 2                                              Gintama°  ...  Gintoki, Shinpachi, and Kagura return as the f...
# 3                                         Steins;Gate 0  ...  The dark untold story of Steins;Gate that lead...
# 4                                           Steins;Gate  ...  The self-proclaimed mad scientist Rintarou Oka...
# ...                                                 ...  ...                                                ...
# 1558                                    Kuroshitsuji II  ...  The stage of Kuroshitsuji II opens on the life...
# 1559                              Minami-ke Natsuyasumi  ...  Second Minami-ke OVA bundled with the 11th vol...
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...  Ninjas with bloodline limits begin disappearin...
# 1561        Persona 4 the Animation: The Factor of Hope  ...  Recap of the entire 25-episode television anim...
# 1562                                       Re:␣Hamatora  ...  It has been three months since the incident at...
#
# [1563 rows x 20 columns]

# %% [markdown]
# # ***Phase de Data Cleaning***

# %% [markdown]
# **On drop les NaN afin  clean notre dataframe**

# %%
# Je décide de drop tous les na dans les datasets afin de supprimer d'éventuels lignes érronées 
df_dataAnime = df_dataAnime.dropna()

# %% [markdown]
# **On renomme le nom de nos colonnes car il y a des espaces dedans**

# %%
df_dataAnime.rename(columns={'Start airing': 'StartingDate', 'End airing': 'EndingDate', 'Starting season':'StartingSeason', 'Broadcast time':'BroadcastTime','Scored by':'ScoredBy'}, inplace=True)
df_dataAnime
# Out:
#                                                   Title  ...                                        Description
# 0                      Fullmetal Alchemist: Brotherhood  ...  "In order for something to be obtained, someth...
# 1                                        Kimi no Na wa.  ...  Mitsuha Miyamizu, a high school girl, yearns t...
# 2                                              Gintama°  ...  Gintoki, Shinpachi, and Kagura return as the f...
# 3                                         Steins;Gate 0  ...  The dark untold story of Steins;Gate that lead...
# 4                                           Steins;Gate  ...  The self-proclaimed mad scientist Rintarou Oka...
# ...                                                 ...  ...                                                ...
# 1558                                    Kuroshitsuji II  ...  The stage of Kuroshitsuji II opens on the life...
# 1559                              Minami-ke Natsuyasumi  ...  Second Minami-ke OVA bundled with the 11th vol...
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...  Ninjas with bloodline limits begin disappearin...
# 1561        Persona 4 the Animation: The Factor of Hope  ...  Recap of the entire 25-episode television anim...
# 1562                                       Re:␣Hamatora  ...  It has been three months since the incident at...
#
# [1563 rows x 20 columns]

# %% [markdown]
# **Ici on vas transformer nos lignes / Colonnes qui peuvent être directement faites**

# %%
# Je vais ensuite transformer mes colonnes qualitative en donnée quantitative via la méthode : "labelencoder"
# Cette méthode permet de trouver toutes les différentes valeur présentes dans une colonne et d'associer une valeur numérique à la place. 
# Si deux valeurs sont identiques elles prennent le même nombre

df_dataAnime['Rating'] = labelencoder.fit_transform(df_dataAnime['Rating'])


# La colonne "Type" possède des valeurs qui peuvent être transformé en booléen. J'utilise la méthode cat.codes

df_dataAnime.Type = df_dataAnime['Type'].astype('category').cat.codes
df_dataAnime.Status = df_dataAnime['Status'].astype('category').cat.codes
df_dataAnime.Sources = df_dataAnime['Sources'].astype('category').cat.codes

# Je décide de supprimer la colonne description, il faudrait créer une recherche afin de déterminer des mots clés importants.

df_dataAnime = df_dataAnime.drop(['Description', 'Producers'], axis= 1)


df_dataAnime
# Out:
#                                                   Title  ...  Favorites
# 0                      Fullmetal Alchemist: Brotherhood  ...     105387
# 1                                        Kimi no Na wa.  ...      33936
# 2                                              Gintama°  ...       5597
# 3                                         Steins;Gate 0  ...       1117
# 4                                           Steins;Gate  ...      90365
# ...                                                 ...  ...        ...
# 1558                                    Kuroshitsuji II  ...       3576
# 1559                              Minami-ke Natsuyasumi  ...          4
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...        129
# 1561        Persona 4 the Animation: The Factor of Hope  ...         12
# 1562                                       Re:␣Hamatora  ...        330
#
# [1563 rows x 18 columns]

# %% [markdown]
# **Fonction dash to unknown**

# %%
# On fait appel à la fonction dash to unknown qui transforme dans une colonne donnée tous les tirets
df_dataAnime.StartingSeason = df_dataAnime.StartingSeason.apply(dashToUnknown)
df_dataAnime
# Out:
#                                                   Title  ...  Favorites
# 0                      Fullmetal Alchemist: Brotherhood  ...     105387
# 1                                        Kimi no Na wa.  ...      33936
# 2                                              Gintama°  ...       5597
# 3                                         Steins;Gate 0  ...       1117
# 4                                           Steins;Gate  ...      90365
# ...                                                 ...  ...        ...
# 1558                                    Kuroshitsuji II  ...       3576
# 1559                              Minami-ke Natsuyasumi  ...          4
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...        129
# 1561        Persona 4 the Animation: The Factor of Hope  ...         12
# 1562                                       Re:␣Hamatora  ...        330
#
# [1563 rows x 18 columns]

# %% [markdown]
# **Maintenant que la colonne StartingSeason ne possède que des valeurs que l'on peut transformer j'utilise la méthode astype**

# %%
# Transformation en valeur quantitative
df_dataAnime.StartingSeason = df_dataAnime['StartingSeason'].astype('category').cat.codes
df_dataAnime
# Out:
#                                                   Title  ...  Favorites
# 0                      Fullmetal Alchemist: Brotherhood  ...     105387
# 1                                        Kimi no Na wa.  ...      33936
# 2                                              Gintama°  ...       5597
# 3                                         Steins;Gate 0  ...       1117
# 4                                           Steins;Gate  ...      90365
# ...                                                 ...  ...        ...
# 1558                                    Kuroshitsuji II  ...       3576
# 1559                              Minami-ke Natsuyasumi  ...          4
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...        129
# 1561        Persona 4 the Animation: The Factor of Hope  ...         12
# 1562                                       Re:␣Hamatora  ...        330
#
# [1563 rows x 18 columns]

# %% [markdown]
# **Afin de pouvoir utiliser la date je souhaite connaitre son type pour pouvoir la  transformer**

# %%
# Pour gérer mes dates je veux savoir leur format de base, c'est donc des objets, il faut les passer en dateTime pour utiliser pandas avec
df_dataAnime.StartingDate.head(5)
# Out:
# 0     2009-4-5
# 1    2016-8-26
# 2     2015-4-8
# 3    2018-4-12
# 4     2011-4-6
# Name: StartingDate, dtype: object

# %% [markdown]
# **J'ai décidé de faire du feature engineering, j'ai remarqué que les types étant des films ne possédait pas de date de fin alors qu'une fois un film sortie il est fini, j'ai donc ajouté aux types "Film" et "OAV" la date de fin = Date de Sortie**

# %%
# Utilisation de la fonction fillEndingDate
df_dataAnime = df_dataAnime.apply(fillEndingDate, axis=1)
df_dataAnime
# Out:
#                                                   Title  ...  Favorites
# 0                      Fullmetal Alchemist: Brotherhood  ...     105387
# 1                                        Kimi no Na wa.  ...      33936
# 2                                              Gintama°  ...       5597
# 3                                         Steins;Gate 0  ...       1117
# 4                                           Steins;Gate  ...      90365
# ...                                                 ...  ...        ...
# 1558                                    Kuroshitsuji II  ...       3576
# 1559                              Minami-ke Natsuyasumi  ...          4
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...        129
# 1561        Persona 4 the Animation: The Factor of Hope  ...         12
# 1562                                       Re:␣Hamatora  ...        330
#
# [1563 rows x 18 columns]

# %% [markdown]
# **Modification du type des dates**

# %%
# Je transforme mes dates via la méthode "to_datetime". Je gère les erreurs via l'argument 'coerce' qui lorsqu'il voit quelque chose ne possédant pas le format choisi assigne la valeur NaT

df_dataAnime.StartingDate = pd.to_datetime(df_dataAnime.StartingDate, 
 format = '%Y-%m-%dT',
 errors = 'coerce')

df_dataAnime.EndingDate = pd.to_datetime(df_dataAnime.EndingDate, 
 format = '%Y-%m-%dT',
 errors = 'coerce')

df_dataAnime
# Out:
#                                                   Title  ...  Favorites
# 0                      Fullmetal Alchemist: Brotherhood  ...     105387
# 1                                        Kimi no Na wa.  ...      33936
# 2                                              Gintama°  ...       5597
# 3                                         Steins;Gate 0  ...       1117
# 4                                           Steins;Gate  ...      90365
# ...                                                 ...  ...        ...
# 1558                                    Kuroshitsuji II  ...       3576
# 1559                              Minami-ke Natsuyasumi  ...          4
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...        129
# 1561        Persona 4 the Animation: The Factor of Hope  ...         12
# 1562                                       Re:␣Hamatora  ...        330
#
# [1563 rows x 18 columns]

# %%
# Maintenant que mes dates sont bien au format DateTime je peut via pandas séparer les dates.
# Je crée des colonnes pour chaque partie de mes dates

df_dataAnime['StartingDate_year'] = df_dataAnime.StartingDate.dt.year
df_dataAnime['StartingDate_month'] = df_dataAnime.StartingDate.dt.month
df_dataAnime['StartingDate_day'] = df_dataAnime.StartingDate.dt.day

df_dataAnime['EndingDate_year'] = df_dataAnime.EndingDate.dt.year
df_dataAnime['EndingDate_month'] = df_dataAnime.EndingDate.dt.month
df_dataAnime['EndingDate_day'] = df_dataAnime.EndingDate.dt.day

# Je drop StartingDate et EndingDate car j'ai fractionné mes dates, je n'en ai plus besoin dans ce format et type

df_dataAnime = df_dataAnime.drop(['StartingDate','EndingDate'], axis= 1)

df_dataAnime
# Out:
#                                                   Title  ...  EndingDate_day
# 0                      Fullmetal Alchemist: Brotherhood  ...             4.0
# 1                                        Kimi no Na wa.  ...            26.0
# 2                                              Gintama°  ...            30.0
# 3                                         Steins;Gate 0  ...             NaN
# 4                                           Steins;Gate  ...            14.0
# ...                                                 ...  ...             ...
# 1558                                    Kuroshitsuji II  ...            17.0
# 1559                              Minami-ke Natsuyasumi  ...             6.0
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...             1.0
# 1561        Persona 4 the Animation: The Factor of Hope  ...             9.0
# 1562                                       Re:␣Hamatora  ...            23.0
#
# [1563 rows x 22 columns]

# %%
# Utilisation de la fonction dashToUnknown
df_dataAnime.BroadcastTime = df_dataAnime.BroadcastTime.apply(dashToUnknown)
df_dataAnime
# Out:
#                                                   Title  ...  EndingDate_day
# 0                      Fullmetal Alchemist: Brotherhood  ...             4.0
# 1                                        Kimi no Na wa.  ...            26.0
# 2                                              Gintama°  ...            30.0
# 3                                         Steins;Gate 0  ...             NaN
# 4                                           Steins;Gate  ...            14.0
# ...                                                 ...  ...             ...
# 1558                                    Kuroshitsuji II  ...            17.0
# 1559                              Minami-ke Natsuyasumi  ...             6.0
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...             1.0
# 1561        Persona 4 the Animation: The Factor of Hope  ...             9.0
# 1562                                       Re:␣Hamatora  ...            23.0
#
# [1563 rows x 22 columns]

# %% [markdown]
# **On continue de transformer nos colonnes** </br>
# **Sur la colonne BroadCastTime on souhaite récupérer le jour et l'heure de sortie des épisodes**

# %%
# On utilise la fonction getBroadcast... qui fait un split sur les espaces pour pouvoir ensuite utilisé seulement ce qui nous intéresse
df_dataAnime['BroadcastDay'] = df_dataAnime.BroadcastTime.apply(getBroadcastDay)
df_dataAnime['BroadcastTime'] = df_dataAnime.BroadcastTime.apply(getBroadcastTime)

# On transforme les valeurs qualitatives en quantitatives
df_dataAnime['BroadcastDay'] = labelencoder.fit_transform(df_dataAnime['BroadcastDay'])
df_dataAnime['BroadcastTime'] = labelencoder.fit_transform(df_dataAnime['BroadcastTime'])

df_dataAnime
# Out:
#                                                   Title  ...  BroadcastDay
# 0                      Fullmetal Alchemist: Brotherhood  ...             4
# 1                                        Kimi no Na wa.  ...             7
# 2                                              Gintama°  ...             8
# 3                                         Steins;Gate 0  ...             5
# 4                                           Steins;Gate  ...             8
# ...                                                 ...  ...           ...
# 1558                                    Kuroshitsuji II  ...             7
# 1559                              Minami-ke Natsuyasumi  ...             7
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...             7
# 1561        Persona 4 the Animation: The Factor of Hope  ...             7
# 1562                                       Re:␣Hamatora  ...             6
#
# [1563 rows x 23 columns]

# %%
# On appelle la fonction getSplittedByBlankSpace afin de pouvoir creer une liste en fonction d'une séparation par un espace.
# Une fois une liste crée on vas encoder chaque ligne et chaque objet via labelEncoder

df_dataAnime.Studios = df_dataAnime.Studios.apply(getSplittedByBlankSpace)

df_dataAnime
# Out:
#                                                   Title  ...  BroadcastDay
# 0                      Fullmetal Alchemist: Brotherhood  ...             4
# 1                                        Kimi no Na wa.  ...             7
# 2                                              Gintama°  ...             8
# 3                                         Steins;Gate 0  ...             5
# 4                                           Steins;Gate  ...             8
# ...                                                 ...  ...           ...
# 1558                                    Kuroshitsuji II  ...             7
# 1559                              Minami-ke Natsuyasumi  ...             7
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...             7
# 1561        Persona 4 the Animation: The Factor of Hope  ...             7
# 1562                                       Re:␣Hamatora  ...             6
#
# [1563 rows x 23 columns]

# %%
# On appelle la fonction getSplittedByComa afin de pouvoir creer une liste en fonction d'une séparation par une virgule.
# Une fois une liste crée on vas encoder chaque ligne et chaque objet via labelEncoder

#df_dataAnime.Producers = df_dataAnime.Producers.apply(getSplittedByComa)
df_dataAnime.Licensors = df_dataAnime.Licensors.apply(getSplittedByComa)
df_dataAnime.Genres = df_dataAnime.Genres.apply(getSplittedByComa)

df_dataAnime
# Out:
#                                                   Title  ...  BroadcastDay
# 0                      Fullmetal Alchemist: Brotherhood  ...             4
# 1                                        Kimi no Na wa.  ...             7
# 2                                              Gintama°  ...             8
# 3                                         Steins;Gate 0  ...             5
# 4                                           Steins;Gate  ...             8
# ...                                                 ...  ...           ...
# 1558                                    Kuroshitsuji II  ...             7
# 1559                              Minami-ke Natsuyasumi  ...             7
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...             7
# 1561        Persona 4 the Animation: The Factor of Hope  ...             7
# 1562                                       Re:␣Hamatora  ...             6
#
# [1563 rows x 23 columns]

# %%
df_dataAnime
# Out:
#                                                   Title  ...  Walt Disney Studios
# 0                      Fullmetal Alchemist: Brotherhood  ...                    0
# 1                                        Kimi no Na wa.  ...                    0
# 2                                              Gintama°  ...                    0
# 3                                         Steins;Gate 0  ...                    0
# 4                                           Steins;Gate  ...                    0
# ...                                                 ...  ...                  ...
# 1558                                    Kuroshitsuji II  ...                    0
# 1559                              Minami-ke Natsuyasumi  ...                    0
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...  ...                    0
# 1561        Persona 4 the Animation: The Factor of Hope  ...                    0
# 1562                                       Re:␣Hamatora  ...                    0
#
# [1563 rows x 70 columns]

# %%
def explodeList(value,columnName) :
  newdf_dataAnime = value.apply(frozenset).to_frame(name=columnName)
  print(newdf_dataAnime)

  for Genres in frozenset.union(*newdf_dataAnime[value]):
    newdf_dataAnime.value = newdf_dataAnime.apply(lambda x: int(value in x.value), axis=1)

explodeList(df_dataAnime.Genres,'Genres')




#copyDf(df_dataAnime.Genres, newdf_dataAnime)
# Out:
#                                                  Genres
# 0     (Action, Shounen, Fantasy, Magic, Adventure, D...
# 1                (Drama, School, Romance, Supernatural)
# 2     (Action, Shounen, Parody, Samurai, Sci-Fi, Com...
# 3                                    (Thriller, Sci-Fi)
# 4                                    (Thriller, Sci-Fi)
# ...                                                 ...
# 1558  (Action, Shounen, Supernatural, Demons, Fantas...
# 1559                            (Slice of Life, Comedy)
# 1560  (Action, Martial Arts, Shounen, Super Power, C...
# 1561  (Supernatural, Super Power, School, Mystery, A...
# 1562              (Mystery, Drama, Comedy, Super Power)
#
# [1563 rows x 1 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-95c15dc39997> in <module>()
#       6     newdf_dataAnime.value = newdf_dataAnime.apply(lambda x: int(value in x.value), axis=1)
#       7
# ----> 8 explodeList(df_dataAnime.Genres,'Genres')
#       9
#      10
#
# <ipython-input-43-95c15dc39997> in explodeList(value, columnName)
#       3   print(newdf_dataAnime)
#       4
# ----> 5   for Genres in frozenset.union(*newdf_dataAnime[value]):
#       6     newdf_dataAnime.value = newdf_dataAnime.apply(lambda x: int(value in x.value), axis=1)
#       7
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1247
#    1248         if ax.is_unique and not getattr(ax, "is_overlapping", False):
# -> 1249             indexer = ax.get_indexer_for(keyarr)
#    1250             keyarr = ax.reindex(keyarr)[0]
#    1251         else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4711         """
#    4712         if self.is_unique:
# -> 4713             return self.get_indexer(target, **kwargs)
#    4714         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4715         return indexer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3004                 )
#    3005
# -> 3006             indexer = self._engine.get_indexer(target._get_engine_target())
#    3007
#    3008         return ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'

# %%
newdf_dataAnime = df_dataAnime.Licensors.apply(frozenset).to_frame(name='Licensors')
print(*newdf_dataAnime.Licensors)

for Licensors in frozenset.union(*newdf_dataAnime.Licensors):
  newdf_dataAnime[Licensors] = newdf_dataAnime.apply(lambda x: int(Licensors in x.Licensors), axis=1)

copyDf(df_dataAnime, newdf_dataAnime)
# Out:
# frozenset({'Aniplex of America', 'Funimation'}) frozenset({'Funimation', 'NYAV Post'}) frozenset({'Crunchyroll', 'Funimation'}) frozenset({'Funimation'}) frozenset({'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'-'}) frozenset({'Viz Media'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({'-'}) frozenset({'NYAV Post'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({'Sentai Filmworks'}) frozenset({'Crunchyroll', 'Sentai Filmworks'}) frozenset({'Sentai Filmworks'}) frozenset({'Bandai Entertainment', 'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'GKIDS', 'Walt Disney Studios'}) frozenset({'Sentai Filmworks'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'Bandai Entertainment', 'Funimation'}) frozenset({'Geneon Entertainment USA'}) frozenset({'GKIDS'}) frozenset({'Bandai Entertainment', 'Funimation'}) frozenset({'Aniplex of America', 'ADV Films'}) frozenset({'Funimation'}) frozenset({'Aniplex of America'}) frozenset({'Aniplex of America'}) frozenset({'Funimation'}) frozenset({'-'}) frozenset({'Discotek Media', 'TOKYOPOP'}) frozenset({'Funimation'}) frozenset({'Aniplex of America', 'Bandai Entertainment'}) frozenset({'-'}) frozenset({'Walt Disney Studios'}) frozenset({'Viz Media'}) frozenset({'Bandai Entertainment', 'Funimation'}) frozenset({' Inc.', 'NIS America'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({'Viz Media'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Funimation'}) frozenset({'Aniplex of America'}) frozenset({'Sentai Filmworks'}) frozenset({'-'}) frozenset({' Inc.', 'NIS America'}) frozenset({'Funimation'}) frozenset({'-'}) frozenset({'Funimation'}) frozenset({'Viz Media'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({' Inc.', 'NIS America'}) frozenset({'-'}) frozenset({'Nozomi Entertainment'}) frozenset({'-'}) frozenset({'Funimation'}) frozenset({'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'Viz Media'}) frozenset({'Sentai Filmworks'}) frozenset({'Aniplex of America', ' Inc.', 'NIS America'}) frozenset({'Bandai Entertainment', 'Manga Entertainment'}) frozenset({'Central Park Media', 'ADV Films', 'Sentai Filmworks'}) frozenset({'-'}) frozenset({'Funimation'}) frozenset({'Funimation'}) frozenset({'Geneon Entertainment USA', 'Flatiron Film Company'}) frozenset({'-'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Funimation', '4Kids Entertainment'}) frozenset({'Geneon Entertainment USA', 'Funimation'}) frozenset({'-'}) frozenset({'Aniplex of America'}) frozenset({'Sentai Filmworks'}) frozenset({'Aniplex of America'}) frozenset({'Bandai Entertainment', 'Funimation'}) frozenset({' Inc.', 'NIS America'}) frozenset({'Funimation'}) frozenset({'Crunchyroll', 'Funimation'}) frozenset({'Funimation'}) frozenset({'-'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Geneon Entertainment USA', 'Funimation'}) frozenset({'Aniplex of America', 'Funimation'}) frozenset({'Media Blasters'}) frozenset({'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'-'}) frozenset({'Funimation'}) frozenset({'Funimation'}) frozenset({'Funimation'}) frozenset({'Sentai Filmworks'}) frozenset({'TMS Entertainment'}) frozenset({'Viz Media'}) frozenset({'GKIDS', 'Walt Disney Studios'}) frozenset({'Aniplex of America'}) frozenset({'Funimation'}) frozenset({'Bandai Entertainment', 'Manga Entertainment'}) frozenset({'Aniplex of America'}) frozenset({'-'}) frozenset({'-'}) frozenset({'Flatiron Film Company'}) frozenset({'Funimation'}) frozenset({'Aniplex of America'}) frozenset({'Funimation'}) frozenset({'-'}) frozenset({'GKIDS', 'Walt Disney Studios'}) frozenset({'Aniplex of America'}) frozenset({' Inc.', 'NIS America'}) frozenset({'ADV Films', 'Sentai Filmworks'}) frozenset({'Aniplex of America'}) frozenset({'Ani ...

# %%
newdf_dataAnime = df_dataAnime.Studios.apply(frozenset).to_frame(name='Studios')

for Studios in frozenset.union(*newdf_dataAnime.Studios):
  newdf_dataAnime[Studios] = newdf_dataAnime.apply(lambda x: int(Studios in x.Studios), axis=1)

copyDf(df_dataAnime, newdf_dataAnime)

# %%
# On Drop les colonnes que l'on viens de modifier car on les à éclatés
df_dataAnime = df_dataAnime.drop(['Licensors', 'Genres','Studios'], axis= 1)

df_dataAnime
# Out:
#                                                   Title  Type  ... Encourage  CoMix
# 0                      Fullmetal Alchemist: Brotherhood     5  ...         0      0
# 1                                        Kimi no Na wa.     0  ...         0      1
# 2                                              Gintama°     5  ...         0      0
# 3                                         Steins;Gate 0     5  ...         0      0
# 4                                           Steins;Gate     5  ...         0      0
# ...                                                 ...   ...  ...       ...    ...
# 1558                                    Kuroshitsuji II     5  ...         0      0
# 1559                              Minami-ke Natsuyasumi     3  ...         0      0
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...     0  ...         0      0
# 1561        Persona 4 the Animation: The Factor of Hope     0  ...         0      0
# 1562                                       Re:␣Hamatora     5  ...         0      0
#
# [1563 rows x 349 columns]

# %%
# J'utilise la fonction getTimePerTitle afin de récupérer le temps par titre, si la ligne possède le texte "per ep" cela signifie que c'est une série et donc il y a plusieurs
# épisodes. Je multiplie donc le temps de l'épisodes par le nombre d'épisodes maximum.

# Je convertis aussi les temps qui sont des heures en minutes

df_dataAnime.Duration = df_dataAnime.Duration.apply(getTimePerTitle)
df_dataAnime
# Out:
#                                                   Title  Type  ... Encourage  CoMix
# 0                      Fullmetal Alchemist: Brotherhood     5  ...         0      0
# 1                                        Kimi no Na wa.     0  ...         0      1
# 2                                              Gintama°     5  ...         0      0
# 3                                         Steins;Gate 0     5  ...         0      0
# 4                                           Steins;Gate     5  ...         0      0
# ...                                                 ...   ...  ...       ...    ...
# 1558                                    Kuroshitsuji II     5  ...         0      0
# 1559                              Minami-ke Natsuyasumi     3  ...         0      0
# 1560  Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsu...     0  ...         0      0
# 1561        Persona 4 the Animation: The Factor of Hope     0  ...         0      0
# 1562                                       Re:␣Hamatora     5  ...         0      0
#
# [1563 rows x 349 columns]

# %%
# Drop na après avoir fait autant de data cleaning
df_dataAnime = df_dataAnime.dropna()

# %%
# Je ne me sers pas de mes titres qui n'ont aucun interêt pour mes algorithmes 
df_dataAnime = df_dataAnime.drop(['Title'], axis= 1)

# %%
# Je supprime tous les tirets restants CAD : 11. En gros tous les titres des séries qui sont toujours en cours
df_dataAnime = df_dataAnime[df_dataAnime.Episodes != '-']
df_dataAnime
# Out:
#       Type Episodes  Status  StartingSeason  ...  Toei  L²Studio Encourage  CoMix
# 0        5       64       1               1  ...     0         0         0      0
# 1        0        1       1               3  ...     0         0         0      1
# 2        5       51       1               1  ...     0         0         0      0
# 4        5       24       1               1  ...     0         0         0      0
# 5        3      110       1               3  ...     0         0         0      0
# ...    ...      ...     ...             ...  ...   ...       ...       ...    ...
# 1558     5       12       1               2  ...     0         0         0      0
# 1559     3        1       1               3  ...     0         0         0      0
# 1560     0        1       1               3  ...     0         0         0      0
# 1561     0        1       1               3  ...     0         0         0      0
# 1562     5       12       1               2  ...     0         0         0      0
#
# [1391 rows x 348 columns]

# %%
# df_dataAnime.loc[df_dataAnime['EndingDate_year'] =='-']

# %%
# Je multiplie par 100 mon score afin d'ensuite pouvoir passer ma colonne en int et ne pas perdre de précieuses informations concernant les virgules
df_dataAnime.Score = df_dataAnime.Score * 100

# Toutes mes colonnes encore en float, je les changes en Int
df_dataAnime.StartingDate_year = df_dataAnime.StartingDate_year.apply(int)
df_dataAnime.StartingDate_month = df_dataAnime.StartingDate_month.apply(int)
df_dataAnime.StartingDate_day = df_dataAnime.StartingDate_day.apply(int)

df_dataAnime.EndingDate_year = df_dataAnime.EndingDate_year.apply(int)
df_dataAnime.EndingDate_month = df_dataAnime.EndingDate_month.apply(int)
df_dataAnime.EndingDate_day = df_dataAnime.EndingDate_day.apply(int)

df_dataAnime

df_dataAnime = df_dataAnime.astype(int)

# %% [markdown]
# # **Isolation des targets et features**

# %%
# J'isole ma target
Y = df_dataAnime['Score']

# J'isole mes features en supprimant ma target et l'adresse IP qui n'a plus d'interet ici 
X = df_dataAnime.drop(['Score'], axis = 1)

# %% [markdown]
# # **Model Building**

# %%
# On vas split notre environnement de travail en 2 grandes parties : L'environnement de prod (test) et d'entrainement (train)
# On vérifie la shape de nos variables afin de s'assurer de possèder le bon nombre de colonnes et de lignes
splits = train_test_split(X,Y,
                          random_state=0)

for each in splits:
  print(each.shape)
X_train, X_test, Y_train, Y_test = splits
scaler = StandardScaler()
# Out:
# (1043, 347)
# (348, 347)
# (1043,)
# (348,)

# %%
#Pipeline
pipeline_details = [('PCA', PCA(random_state=20)),
                    ('RF', RF()),
                    ('KNN',KNN(n))]
pipeline = Pipeline(steps=pipeline_details)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1140-cbbb44ed64ff> in <module>()
#       3                     ('RF', RF()),
#       4                     ('KNN',KNN())]
# ----> 5 pipeline = Pipeline(steps=pipeline_details)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in __init__(self, steps, memory, verbose)
#     134         self.memory = memory
#     135         self.verbose = verbose
# --> 136         self._validate_steps()
#     137
#     138     def get_params(self, deep=True):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in _validate_steps(self)
#     182                                 "transformers and implement fit and transform "
#     183                                 "or be the string 'passthrough' "
# --> 184                                 "'%s' (type %s) doesn't" % (t, type(t)))
#     185
#     186         # We allow last estimator to be None as an identity transformation
#
# TypeError: All intermediate steps should be transformers and implement fit and transform or be the string 'passthrough' 'RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)' (type <class 'sklearn.ensemble._forest.RandomForestClassifier'>) doesn't

# %%
#GridSearchCV
#limité pour cause de performance


hyperparameters = {}
hyperparameters['PCA__n_components'] = [i for i in range(1, 5)]
hyperparameters['RF__n_estimators']  = [i for i in range(80, 120 +1, 10)]
hyperparameters['knn__n_neighbors'] = [1, 3, 5, 9, 21]
#hyperparameters['PCA__n_components'] = [5]
#hyperparameters['RF__n_estimators']  = [100]

hyperparameters

hyperparameter_search = GridSearchCV(pipeline,
                                     hyperparameters,
                                     scoring='accuracy', 
                                     cv=3)

hyperparameter_search.fit(X_train, Y_train)

print('Meilleur score : {:.5f}'.format(hyperparameter_search.best_score_))
print('Meilleur paramètres : {}'.format(hyperparameter_search.best_params_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1139-529af3003266> in <module>()
#      17                                      cv=3)
#      18
# ---> 19 hyperparameter_search.fit(X_train, Y_train)
#      20
#      21 print('Meilleur score : {:.5f}'.format(hyperparameter_search.best_score_))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     502             cloned_parameters[k] = clone(v, safe=False)
#     503
# --> 504         estimator = estimator.set_params(**cloned_parameters)
#     505
#     506     start_time = time.time()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in set_params(self, **kwargs)
#     161         self
#     162         """
# --> 163         self._set_params('steps', **kwargs)
#     164         return self
#     165
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/metaestimators.py in _set_params(self, attr, **params)
#      48                 self._replace_estimator(attr, name, params.pop(name))
#      49         # 3. Step parameters and other initialisation arguments
# ---> 50         super().set_params(**params)
#      51         return self
#      52
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in set_params(self, **params)
#     234                                  'Check the list of available parameters '
#     235                                  'with `estimator.get_params().keys()`.' %
# --> 236                                  (key, self))
#     237
#     238             if delim:
#
# ValueError: Invalid parameter knn for estimator Pipeline(memory=None,
#          steps=[('PCA',
#                  PCA(copy=True, iterated_power='auto', n_components=None,
#                      random_state=20, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('RF',
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
#PCA
N=hyperparameter_search.best_params_['PCA__n_components']
pca = PCA(n_components=N, random_state=20)
pca.fit(X_train);

# %%
#Transform
X_train_PCA = pca.transform(X_train)
X_test_PCA = pca.transform(X_test)

# %%
#RF
N=hyperparameter_search.best_params_['RF__n_estimators']
rf = RF(n_estimators=N)
rf.fit(X_train_PCA, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=110,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Accuracy du training
train_preds = rf.predict(X_train_PCA)
print('Accuracy : {}'.format(accuracy(train_preds, Y_train)))
# Out:
# Accuracy : 1.0

# %% [markdown]
# # ***RANDOM FOREST CLASSIFIER***

# %%
# On applique l'algorithme RandomForest
rf = RF()
rf.fit(X_train,Y_train)
Y_pred = rf.predict(X_test)
proba = rf.predict_proba(X_test)

# %%
# On observe une accuracy de 94% dans ce test avec comme hyperparamètre random_state=0
accuracy(Y_pred,Y_test)
# Out:
# 0.017241379310344827

# %% [markdown]
# # ***KNN***

# %%
#Passage des HYPERPARAMETRES
knn = KNN(n_neighbors=97)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=97, p=2,
#                      weights='uniform')

# %%
Y_pred = knn.predict(X_test)
accuracy(Y_pred, Y_test)
# Out:
# 0.014367816091954023

# %% [markdown]
# # **Matrice de Confusion**

# %%
classes = Y.astype('category').cat.categories.tolist()

# %%
def show_cm(cm, labels):
    df_cm = pd.DataFrame(cm, labels, labels)
    sns.heatmap(df_cm, annot=True)
    plt.show()

# %%
cm_train = confusion_matrix(Y_pred, Y_test, labels=classes)
show_cm(cm_train, classes)
#Accuracy du training
accuracy = lambda p, y : (p==y).sum()/len(y)
print('Accuracy : {}'.format(accuracy(Y_pred, Y_test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1135-c78f46ee6490> in <module>()
#       1 cm_train = confusion_matrix(Y_pred, Y_test, labels=classes)
# ----> 2 show_cm(cm_train, classes)
#       3 #Accuracy du training
#       4 accuracy = lambda p, y : (p==y).sum()/len(y)
#       5 print('Accuracy : {}'.format(accuracy(Y_pred, Y_test)))
#
# <ipython-input-1134-9cd784095868> in show_cm(cm, labels)
#       2     df_cm = pd.DataFrame(cm, labels, labels)
#       3     sns.heatmap(df_cm, annot=True)
# ----> 4     plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # **Importance des features**

# %%
# Ici on vas réentrainer notre model pour faire un test d'importance sur nos features
rf.fit(X_train, Y_train)
importance = rf.feature_importances_
importance
# Out:
# array([1.37936453e-02, 2.97366156e-02, 6.71905359e-04, 2.02127127e-02,
#        1.93037303e-02, 2.47942738e-02, 3.50633474e-02, 1.62464719e-02,
#        4.65797772e-02, 4.69660366e-02, 4.58087048e-02, 3.85997787e-02,
#        3.09741441e-02, 3.94850925e-02, 3.68562618e-02, 3.03148839e-02,
#        3.97949832e-02, 1.78938192e-02, 5.37487567e-04, 3.63199165e-03,
#        1.00422488e-02, 2.46197982e-03, 3.43695953e-03, 5.73277258e-03,
#        1.12973193e-02, 1.42986607e-02, 2.72546019e-03, 2.69335059e-03,
#        1.00014716e-02, 2.54988079e-03, 1.65971060e-03, 1.09783587e-02,
#        4.17630737e-03, 2.98486025e-03, 6.02564195e-03, 1.06164053e-02,
#        3.82656254e-04, 6.75065934e-03, 0.00000000e+00, 5.06092849e-03,
#        1.44630676e-03, 5.85315175e-03, 1.02007600e-02, 2.81070451e-03,
#        2.38379400e-03, 1.24288245e-02, 6.54984751e-03, 1.37767520e-03,
#        8.85943328e-03, 4.79230209e-03, 1.58767535e-03, 1.20336601e-03,
#        7.36239936e-03, 6.76745802e-03, 1.05977387e-02, 1.36912676e-02,
#        3.64239734e-03, 2.56321568e-03, 1.34060166e-03, 1.38974145e-03,
#        4.54762366e-04, 3.05227264e-04, 0.00000000e+00, 2.39622852e-03,
#        5.67024205e-04, 1.07696717e-04, 2.18517546e-03, 2.74778071e-03,
#        1.24987148e-03, 1.29636038e-04, 1.33652478e-03, 3.20362629e-03,
#        4.84537467e-04, 7.18711519e-04, 3.94671914e-03, 3.40976627e-03,
#        1.42621360e-04, 3.19787270e-04, 1.07255833e-02, 4.50180291e-04,
#        4.93928516e-04, 3.32904918e-03, 1.33195762e-03, 7.97252658e-03,
#        6.09131282e-04, 0.00000000e+00, 1.38128843e-04, 1.96988191e-03,
#        6.52415266e-05, 7.08946250e-04, 7.92519454e-04, 7.56121387e-04,
#        5.47112452e-04, 9.70391406e-04, 2.17675097e-03, 0.00000000e+00,
#        2.74874249e-04, 5.47876791e-04, 2.71817453e-04, 2.87105788e-04,
#        4.15225862e-03, 2.83396681e-03, 2.19765999e-04, 3.44165203e-04,
#        2.64695465e-04, 0.00000000e+00, 4.21798575e-04, 7.18323559e-04,
#        9.53979966e-04, 0.00000000e+00, 0.00000000e+00, 4.51616988e-04,
#        1.33251228e-03, 6.97362444e-04, 9.23702702e-04, 0.00000000e+00,
#        2.26657154e-04, 2.76219272e-04, 3.86470831e-04, 1.04447853e-03,
#        0.00000000e+00, 2.15109908e-04, 4.88455028e-04, 3.90206236e-04,
#        4.12218457e-03, 7.37464010e-04, 1.69930309e-04, 3.47295576e-04,
#        0.00000000e+00, 1.22259146e-03, 7.80342169e-04, 0.00000000e+00,
#        2.63069023e-04, 2.28807755e-04, 0.00000000e+00, 5.33850537e-04,
#        3.36260226e-04, 2.67492678e-04, 0.00000000e+00, 2.66405083e-04,
#        7.17456332e-04, 6.59229560e-04, 2.44576672e-04, 2.26179233e-04,
#        1.98856164e-04, 2.42737787e-04, 0.00000000e+00, 2.26834552e-04,
#        7.09667479e-04, 0.00000000e+00, 5.85018036e-03, 2.65052957e-04,
#        7.26156794e-04, 0.00000000e+00, 1.64818556e-04, 7.33451299e-04,
#        0.00000000e+00, 5.04242238e-04, 9.47159326e-04, 1.99120359e-04,
#        1.38167710e-04, 3.50158551e-04, 2.28347760e-04, 1.25258175e-03,
#        3.86661449e-04, 5.54157304e-04, 1.16589667e-03, 1.49575191e-04,
#        2.91778827e-04, 2.81166737e-04, 5.55814881e-04, 0.00000000e+00,
#        0.00000000e+00, 3.88757027e-04, 8.63070601e-04, 7.88582768e-04,
#        0.00000000e+00, 4.89636449e-04, 1.23450199e-03, 4.28309492e-04,
#        2.25067000e-04, 1.63175175e-04, 7.01360487e-04, 5.33159406e-04,
#        0.00000000e+00, 2.47382980e-04, 1.99543092e-04, 0.00000000e+00,
#        3.77677478e-03, 7.92946281e-04, 2.19474387e-04, 3.95009972e-04,
#        2.60864431e-04, 2.90531843e-04, 2.60152355e-04, 0.00000000e+00,
#        0.00000000e+00, 1.17180935e-03, 2.60298639e-04, 2.80251186e-04,
#        4.23788651e-04, 6.64995397e-04, 1.87397976e-04, 3.65085001e-04,
#        4.83128047e-04, 0.00000000e+00, 0.00000000e+00, 1.20094896e-03,
#        0.00000000e+00, 3.17660184e-04, 2.46356560e-04, 2.21729613e-04,
#        5.89975515e-04, 4.18080725e-04, 8.63872190e-04, 7.07923726e-04,
#        8.87065089e-04, 2.80915028e-04, 1.72410655e-04, 1.44441735e-04,
#        0.00000000e+00, 3.52787461e-03, 3.65246683e-04, 9.26174042e-04,
#        2.08351654e-04, 4.30952509e-04, 1.10629387e-04, 8.76802831e-04,
#        1.99091911e-03, 3.70478099e-04, 1.52861462e-03, 0.00000000e+00,
#        1.66231070e-04, 4.94310183e-03, 0.00000000e+00, 9.94046444e-05,
#        0.00000000e+00, 1.42071398e-04, 3.09470344e-03, 2.42564424e-03,
#        3.84367826e-03, 3.23761465e-04, 3.29179641e-04, 0.00000000e+00,
#        3.72231656e-04, 1.73912096e-03, 1.05097706e-04, 1.57404927e-03,
#        8.33691487e-05, 2.12416487e-04, 1.05604061e-03, 0.00000000e+00,
#        0.00000000e+00, 7.52972097e-04, 1.37352296e-03, 4.18384631e-04,
#        4.04736134e-04, 4.17138165e-03, 1.13316703e-03, 5.54499547e-04,
#        1.45718342e-04, 1.15282498e-03, 1.23365895e-03, 0.00000000e+00,
#        1.33049798e-03, 2.13602434e-03, 0.00000000e+00, 4.99230120e-03,
#        1.74694284e-04, 7.88380870e-04, 2.51228637e-04, 8.44079682e-03,
#        9.96368085e-05, 2.24702014e-04, 5.21090662e-04, 0.00000000e+00,
#        0.00000000e+00, 1.57481536e-03, 3.44697112e-04, 5.17272649e-04,
#        0.00000000e+00, 0.00000000e+00, 1.64705743e-03, 0.00000000e+00,
#        1.26037680e-03, 4.86497948e-04, 0.00000000e+00, 1.55172871e-04,
#        0.00000000e+00, 0.00000000e+00, 5.21738042e-04, 1.84987866e-04,
#        2.11743183e-04, 2.30632358e-04, 4.02457230e-03, 4.02552383e-05,
#        8.87904609e-04, 0.00000000e+00, 3.59326252e-04, 8.89570639e-04,
#        4.08045593e-03, 1.16487672e-03, 2.57794686e-04, 9.32721291e-04,
#        2.06221766e-04, 6.64702325e-04, 7.67310858e-04, 4.12857136e-04,
#        0.00000000e+00, 2.13615022e-04, 2.14053610e-04, 1.47077771e-04,
#        8.74688916e-04, 2.58340281e-04, 2.29374495e-04, 1.75097623e-04,
#        2.75932701e-03, 2.81248164e-04, 3.19934501e-03, 1.08875433e-03,
#        2.02986456e-04, 3.30711645e-04, 4.91995452e-04, 4.72737829e-04,
#        3.74103170e-04, 5.09565501e-03, 1.06823791e-03, 0.00000000e+00,
#        4.92736057e-04, 1.63173366e-04, 2.21723539e-04, 8.17633352e-04,
#        1.48979135e-03, 9.57463173e-04, 1.97115965e-04, 6.79370752e-04,
#        1.38360675e-04, 2.06921749e-04, 0.00000000e+00, 6.53623726e-04,
#        1.31100486e-03, 1.70018627e-03, 3.10648442e-03, 4.69334806e-03,
#        2.59450371e-04, 1.88014844e-04, 4.27642254e-04])

# %%
# Une fois l'importance réalisé on vas la plot afin mieux observer à quel point une feature peut faire varier notre accuracy
# Je crée un nouveau dataframe pour pouvoir stocker seulement les colonnes qui m'intéresse

d = pd.DataFrame()
d['features'] = X_train.columns
d['pouvoir_predictif'] = importance
print('Somme des pouvoirs predictif : {}'.format(d['pouvoir_predictif'].sum()))
d['pouvoir_predictif'] = d['pouvoir_predictif'].apply(lambda v : v*100)
d = d.sort_values(by='pouvoir_predictif', ascending=True)
sns.barplot(d['pouvoir_predictif'], d['features']).set_title('Pouvoir predictif des features');
# Out:
# Somme des pouvoirs predictif : 1.0000000000000002

# %%
d
# Out:
#              features  pouvoir_predictif
# 149       Enterprises           0.000000
# 205     Artland,Magic           0.000000
# 289          Deen,DAX           0.000000
# 236         Yaoyorozu           0.000000
# 286      Actas,Studio           0.000000
# ..                ...                ...
# 13   StartingDate_day           3.948509
# 16     EndingDate_day           3.979498
# 10          Favorites           4.580870
# 8            ScoredBy           4.657978
# 9             Members           4.696604
#
# [347 rows x 2 columns]

# %%
n_classes = 2
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(Y_test, proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(Y_test.ravel(), proba[:, i].ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])


plt.figure()
lw = 2
plt.plot(fpr[1], tpr[1], color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[1])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1077-5775733635dc> in <module>()
#       4 roc_auc = dict()
#       5 for i in range(n_classes):
# ----> 6     fpr[i], tpr[i], _ = roc_curve(Y_test, proba[:, i])
#       7     roc_auc[i] = auc(fpr[i], tpr[i])
#       8
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     769     """
#     770     fps, tps, thresholds = _binary_clf_curve(
# --> 771         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     772
#     773     # Attempt to drop thresholds corresponding to points in between and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     534     if not (y_type == "binary" or
#     535             (y_type == "multiclass" and pos_label is not None)):
# --> 536         raise ValueError("{0} format is not supported".format(y_type))
#     537
#     538     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1078-8cf122888b49> in <module>()
#       1 # First aggregate all false positive rates
# ----> 2 all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
#       3
#       4 # Then interpolate all ROC curves at this points
#       5 mean_tpr = np.zeros_like(all_fpr)
#
# <ipython-input-1078-8cf122888b49> in <listcomp>(.0)
#       1 # First aggregate all false positive rates
# ----> 2 all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
#       3
#       4 # Then interpolate all ROC curves at this points
#       5 mean_tpr = np.zeros_like(all_fpr)
#
# KeyError: 0

# %%
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
